# %%
# -*- coding: utf-8 -*-
"""
@author: zhanghui
@software: jupyter
@file: origin.ipynb
@time: 2021-1-4
@description：
"""
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
submit = pd.read_csv('../data/submit.csv')
train.shape, test.shape, submit.shape
# Out:
# ((40000, 21), (15000, 20), (15000, 2))

# %%
train.head()
# Out:
#         id  XINGBIE        CSNY  HYZK  ZHIYE  ZHICHEN  ZHIWU  XUELI  DWJJLX  \
# 0  train_0        1  1038672000    90     90      999      0     99     150
# 1  train_1        2   504892800    90     90      999      0     99     110
# 2  train_2        1   736185600    90     90      999      0     99     150
# 3  train_3        1   428515200    90     90      999      0     99     150
# 4  train_4        2   544204800    90     90      999      0     99     900
#
#    DWSSHY  ...  GRZHZT      GRZHYE  GRZHSNJZYE  GRZHDNGJYE   GRYJCE   DWYJCE  \
# 0      12  ...       1    3223.515     801.310     837.000   312.00   312.00
# 1       0  ...       1   18055.195   53213.220    1065.200   795.84   795.84
# 2       9  ...       1   27426.600   13963.140    7230.020  1444.20  1444.20
# 3       7  ...       1  111871.130   99701.265    2271.295  1417.14  1417.14
# 4      14  ...       1     237.000   11028.875      35.780   325.50   325.50
#
#     DKFFE        DKYE   DKLL  label
# 0  175237  154112.935  2.708      0
# 1  300237  298252.945  2.979      0
# 2  150237  147339.130  2.708      0
# 3  350237  300653.780  2.708      0
# 4  150237  145185.010  2.708      0
#
# [5 rows x 21 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          40000 non-null  object
#  1   XINGBIE     40000 non-null  int64
#  2   CSNY        40000 non-null  int64
#  3   HYZK        40000 non-null  int64
#  4   ZHIYE       40000 non-null  int64
#  5   ZHICHEN     40000 non-null  int64
#  6   ZHIWU       40000 non-null  int64
#  7   XUELI       40000 non-null  int64
#  8   DWJJLX      40000 non-null  int64
#  9   DWSSHY      40000 non-null  int64
#  10  GRJCJS      40000 non-null  float64
#  11  GRZHZT      40000 non-null  int64
#  12  GRZHYE      40000 non-null  float64
#  13  GRZHSNJZYE  40000 non-null  float64
#  14  GRZHDNGJYE  40000 non-null  float64
#  15  GRYJCE      40000 non-null  float64
#  16  DWYJCE      40000 non-null  float64
#  17  DKFFE       40000 non-null  int64
#  18  DKYE        40000 non-null  float64
#  19  DKLL        40000 non-null  float64
#  20  label       40000 non-null  int64
# dtypes: float64(8), int64(12), object(1)
# memory usage: 6.4+ MB

# %%
cate_cols = ['HYZK', 'ZHIYE', 'ZHICHEN', 'DWJJLX', 'DWSSHY', 'GRZHZT','XINGBIE', 'ZHIWU', 'XUELI']
train[cate_cols]
# Out:
#        HYZK  ZHIYE  ZHICHEN  DWJJLX  DWSSHY  GRZHZT  XINGBIE  ZHIWU  XUELI
# 0        90     90      999     150      12       1        1      0     99
# 1        90     90      999     110       0       1        2      0     99
# 2        90     90      999     150       9       1        1      0     99
# 3        90     90      999     150       7       1        1      0     99
# 4        90     90      999     900      14       1        2      0     99
# ...     ...    ...      ...     ...     ...     ...      ...    ...    ...
# 39995    90     90      999     110      16       1        1      0     99
# 39996    90     90      999     110      14       1        2      0     99
# 39997    90     90      999     143       9       1        2      0     99
# 39998    90     90      999     150       6       1        1      0     99
# 39999    90     90      999     110      14       1        1      0     99
#
# [40000 rows x 9 columns]

# %%
num_cols = ['GRJCJS', 'GRZHYE', 'GRZHSNJZYE', 'GRZHDNGJYE', 'GRYJCE', 'DWYJCE','DKFFE', 'DKYE', 'DKLL']
train[num_cols]
# Out:
#         GRJCJS      GRZHYE  GRZHSNJZYE  GRZHDNGJYE   GRYJCE   DWYJCE   DKFFE  \
# 0       1737.0    3223.515     801.310     837.000   312.00   312.00  175237
# 1       4894.0   18055.195   53213.220    1065.200   795.84   795.84  300237
# 2      10297.0   27426.600   13963.140    7230.020  1444.20  1444.20  150237
# 3      10071.5  111871.130   99701.265    2271.295  1417.14  1417.14  350237
# 4       2007.0     237.000   11028.875      35.780   325.50   325.50  150237
# ...        ...         ...         ...         ...      ...      ...     ...
# 39995   3185.0   82865.575   65304.370    4026.600   590.76   590.76  150237
# 39996   1660.5   32811.585   27065.150    1603.560   407.82   407.82  300237
# 39997   3923.0    8875.695    1309.890    3185.800   605.60   605.60  175237
# 39998   3527.0    2079.400     252.875    1614.490   467.30   467.30  125237
# 39999   4934.5   26210.635   27266.080   -4994.610   800.70   800.70  300237
#
#              DKYE   DKLL
# 0      154112.935  2.708
# 1      298252.945  2.979
# 2      147339.130  2.708
# 3      300653.780  2.708
# 4      145185.010  2.708
# ...           ...    ...
# 39995  117816.680  2.708
# 39996  267615.065  2.979
# 39997     237.000  2.708
# 39998  113068.900  2.708
# 39999  287737.000  2.979
#
# [40000 rows x 9 columns]

# %% [markdown]
# 特征工程

# %%
df = pd.concat([train, test], axis = 0).reset_index(drop = True)

# %%
df['missing_rate'] = (df.shape[1] - df.count(axis = 1)) / df.shape[1]

df['DKFFE_DKYE'] = df['DKFFE'] + df['DKYE']
df['DKFFE_DKY_multi_DKLL'] = (df['DKFFE'] + df['DKYE']) * df['DKLL']
df['DKFFE_multi_DKLL'] = df['DKFFE'] * df['DKLL']
df['DKYE_multi_DKLL'] = df['DKYE'] * df['DKLL']
df['GRYJCE_DWYJCE'] = df['GRYJCE'] + df['DWYJCE']
df['GRZHDNGJYE_GRZHSNJZYE'] = df['GRZHDNGJYE'] + df['GRZHSNJZYE']

df['DKFFE_multi_DKLL_ratio'] = df['DKFFE'] * df['DKLL'] / df['DKFFE_DKY_multi_DKLL']
df['DKYE_multi_DKLL_ratio'] = df['DKYE'] * df['DKLL'] / df['DKFFE_DKY_multi_DKLL']
df['DKYE_DKFFE_ratio'] = df['DKYE'] / df['DKFFE_DKYE']
df['DKFFE_DKYE_ratio'] = df['DKFFE'] / df['DKFFE_DKYE']
df['GRZHYE_diff_GRZHDNGJYE'] = df['GRZHYE'] - df['GRZHDNGJYE']
df['GRZHYE_diff_GRZHSNJZYE'] = df['GRZHYE'] - df['GRZHSNJZYE']
df['GRYJCE_DWYJCE_ratio'] = df['GRYJCE'] / df['GRYJCE_DWYJCE']
df['DWYJCE_GRYJCE_ratio'] = df['DWYJCE'] / df['GRYJCE_DWYJCE']


gen_feats = ['DKFFE_DKYE', 'DKFFE_DKY_multi_DKLL', 'DKFFE_multi_DKLL', 'DKYE_multi_DKLL', 'GRYJCE_DWYJCE', 
             'GRZHDNGJYE_GRZHSNJZYE', 'DKFFE_multi_DKLL_ratio', 'DKYE_multi_DKLL_ratio', 'GRZHYE_diff_GRZHDNGJYE',
            'GRZHYE_diff_GRZHSNJZYE', 'GRYJCE_DWYJCE_ratio', 'DWYJCE_GRYJCE_ratio', 'DKYE_DKFFE_ratio', 'DKFFE_DKYE_ratio']

df.head()
# Out:
#         id  XINGBIE        CSNY  HYZK  ZHIYE  ZHICHEN  ZHIWU  XUELI  DWJJLX  \
# 0  train_0        1  1038672000    90     90      999      0     99     150
# 1  train_1        2   504892800    90     90      999      0     99     110
# 2  train_2        1   736185600    90     90      999      0     99     150
# 3  train_3        1   428515200    90     90      999      0     99     150
# 4  train_4        2   544204800    90     90      999      0     99     900
#
#    DWSSHY  ...  GRYJCE_DWYJCE  GRZHDNGJYE_GRZHSNJZYE  DKFFE_multi_DKLL_ratio  \
# 0      12  ...         624.00               1638.310                0.532069
# 1       0  ...        1591.68              54278.420                0.501658
# 2       9  ...        2888.40              21193.160                0.504869
# 3       7  ...        2834.28             101972.560                0.538089
# 4      14  ...         651.00              11064.655                0.508550
#
#    DKYE_multi_DKLL_ratio  DKYE_DKFFE_ratio  DKFFE_DKYE_ratio  \
# 0               0.467931          0.467931          0.532069
# 1               0.498342          0.498342          0.501658
# 2               0.495131          0.495131          0.504869
# 3               0.461911          0.461911          0.538089
# 4               0.491450          0.491450          0.508550
#
#    GRZHYE_diff_GRZHDNGJYE  GRZHYE_diff_GRZHSNJZYE  GRYJCE_DWYJCE_ratio  \
# 0                2386.515                2422.205                  0.5
# 1               16989.995              -35158.025                  0.5
# 2               20196.580               13463.460                  0.5
# 3              109599.835               12169.865                  0.5
# 4                 201.220              -10791.875                  0.5
#
#    DWYJCE_GRYJCE_ratio
# 0                  0.5
# 1                  0.5
# 2                  0.5
# 3                  0.5
# 4                  0.5
#
# [5 rows x 36 columns]

# %%
# def get_age(df,col = 'age'):
#     df[col+"_genFeat1"]=(df['age'] > 18).astype(int)
#     df[col+"_genFeat2"]=(df['age'] > 25).astype(int)
#     df[col+"_genFeat3"]=(df['age'] > 30).astype(int)
#     df[col+"_genFeat4"]=(df['age'] > 35).astype(int)
#     df[col+"_genFeat5"]=(df['age'] > 40).astype(int)
#     df[col+"_genFeat6"]=(df['age'] > 45).astype(int)
#     return df, [col + f'_genFeat{i}' for i in range(1, 7)]

# df['age'] = ((1609430399 - df['CSNY']) / (365 * 24 * 3600)).astype(int)
# df, genFeats1 = get_age(df, col = 'age')

# sns.distplot(df['age'][df['age'] > 0])

# %%
# def get_daikuanYE(df,col):
#     df[col + '_genFeat1'] = (df[col] > 100000).astype(int)
#     df[col + '_genFeat2'] = (df[col] > 120000).astype(int)
#     df[col + '_genFeat3'] = (df[col] > 140000).astype(int)
#     df[col + '_genFeat4'] = (df[col] > 180000).astype(int)
#     df[col + '_genFeat5'] = (df[col] > 220000).astype(int)
#     df[col + '_genFeat6'] = (df[col] > 260000).astype(int)
#     df[col + '_genFeat7'] = (df[col] > 300000).astype(int)
#     return df, [col + f'_genFeat{i}' for i in range(1, 8)]

# df, genFeats2 = get_daikuanYE(df, col = 'DKYE')
# df, genFeats3 = get_daikuanYE(df, col = 'DKFFE')


# plt.figure(figsize = (8, 2))
# plt.subplot(1,2,1)
# sns.distplot(df['DKYE'][df['label'] == 1])
# plt.subplot(1,2,2)
# sns.distplot(df['DKFFE'][df['label'] == 1])
# plt.show()

# %%
# for f in tqdm(cate_cols):
#     df[f] = df[f].map(dict(zip(df[f].unique(), range(df[f].nunique()))))
#     df[f + '_count'] = df[f].map(df[f].value_counts())
#     df = pd.concat([df,pd.get_dummies(df[f],prefix=f"{f}")],axis=1)
    
    
# cate_cols_combine = [[cate_cols[i], cate_cols[j]] for i in range(len(cate_cols)) \
#                      for j in range(i + 1, len(cate_cols))]


# for f1, f2 in tqdm(cate_cols_combine):
#     df['{}_{}_count'.format(f1, f2)] = df.groupby([f1, f2])['id'].transform('count')
#     df['{}_in_{}_prop'.format(f1, f2)] = df['{}_{}_count'.format(f1, f2)] / df[f2 + '_count']
#     df['{}_in_{}_prop'.format(f2, f1)] = df['{}_{}_count'.format(f1, f2)] / df[f1 + '_count']

    
for f1 in tqdm(cate_cols):
    g = df.groupby(f1)
    for f2 in num_cols + gen_feats:
        for stat in ['sum', 'mean', 'std', 'max', 'min', 'std']:
            df['{}_{}_{}'.format(f1, f2, stat)] = g[f2].transform(stat)
#     for f3 in genFeats2 + genFeats3:
#         for stat in ['sum', 'mean']:
#             df['{}_{}_{}'.format(f1, f2, stat)] = g[f2].transform(stat)

# num_cols_gen_feats = num_cols + gen_feats
# for f1 in tqdm(num_cols_gen_feats):
#     g = df.groupby(f1)
#     for f2 in num_cols_gen_feats:
#         if f1 != f2:
#             for stat in ['sum', 'mean', 'std', 'max', 'min', 'std']:
#                 df['{}_{}_{}'.format(f1, f2, stat)] = g[f2].transform(stat)

# for i in tqdm(range(len(num_cols_gen_feats))):
#     for j in range(i + 1, len(num_cols_gen_feats)):
#         df[f'numsOf_{num_cols_gen_feats[i]}_{num_cols_gen_feats[j]}_add'] = df[num_cols_gen_feats[i]] + df[num_cols_gen_feats[j]]
#         df[f'numsOf_{num_cols_gen_feats[i]}_{num_cols_gen_feats[j]}_diff'] = df[num_cols_gen_feats[i]] - df[num_cols_gen_feats[j]]
#         df[f'numsOf_{num_cols_gen_feats[i]}_{num_cols_gen_feats[j]}_multi'] = df[num_cols_gen_feats[i]] * df[num_cols_gen_feats[j]]
#         df[f'numsOf_{num_cols_gen_feats[i]}_{num_cols_gen_feats[j]}_div'] = df[num_cols_gen_feats[i]] / (df[num_cols_gen_feats[j]] + 0.0000000001)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.87it/s]

# %% [markdown]
# 训练集、测试集

# %%
train_df = df[df['label'].isna() == False].reset_index(drop=True)
test_df = df[df['label'].isna() == True].reset_index(drop=True)
display(train_df.shape, test_df.shape)
# Out:
# (40000, 1071)
# (15000, 1071)

# %%
drop_feats = [f for f in train_df.columns if train_df[f].nunique() == 1 or train_df[f].nunique() == 0]
len(drop_feats)
# Out:
# 97

# %%
cols = [col for col in train_df.columns if col not in ['id', 'label'] + drop_feats]

# %%
len(cols)
# Out:
# 972

# %%
train_df.fillna(train_df.mean(), inplace=True)

# %%
train_df.shape
# Out:
# (40000, 1071)

# %%
from sklearn.model_selection import StratifiedKFold
from lightgbm.sklearn import LGBMClassifier
from sklearn.metrics import f1_score, roc_auc_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
import time

# %%
def custom_f1_eval(y_true, y_pred):
    num_TP = 0
    threshold = 0.5
    for i in range(len(y_true)):
        if y_pred >= threshold:
            num_pred += 1
            if y_true == 1:
                num_TP += 1
    precision = num_TP / num_pred
    recall = num_TP / len(y_true[y_true == 1])
    f1 = 2 * precision * recall / (precision + recall)
    return "f1", f1_mean, True

# %%
def judge(y_true,y_pred):
    d = pd.DataFrame()
    d['prob'] = list(y_pred)
    d['y'] = list(y_true)
    d = d.sort_values(['prob'], ascending=[0])
    y = d.y
    PosAll = pd.Series(y).value_counts()[1]
    NegAll = pd.Series(y).value_counts()[0]
    pCumsum = d['y'].cumsum()
    nCumsum = np.arange(len(y)) - pCumsum + 1
    pCumsumPer = pCumsum / PosAll
    nCumsumPer = nCumsum / NegAll
    TR1 = pCumsumPer[abs(nCumsumPer-0.001).idxmin()]
    TR2 = pCumsumPer[abs(nCumsumPer-0.005).idxmin()]
    TR3 = pCumsumPer[abs(nCumsumPer-0.01).idxmin()]
    return 'score',0.4 * TR1 + 0.3 * TR2 + 0.3 * TR3, True

# %%
def tpr_weight_funtion(y_true,y_predict):
    d = pd.DataFrame()
    d['prob'] = list(y_predict)
    d['y'] = list(y_true)
    d = d.sort_values(['prob'], ascending=[0])
    y = d.y
    PosAll = pd.Series(y).value_counts()[1]
    NegAll = pd.Series(y).value_counts()[0]
    pCumsum = d['y'].cumsum()
    nCumsum = np.arange(len(y)) - pCumsum + 1
    pCumsumPer = pCumsum / PosAll
    nCumsumPer = nCumsum / NegAll
    TR1 = pCumsumPer[abs(nCumsumPer-0.001).idxmin()]
    TR2 = pCumsumPer[abs(nCumsumPer-0.005).idxmin()]
    TR3 = pCumsumPer[abs(nCumsumPer-0.01).idxmin()]
    
    return 0.4 * TR1 + 0.3 * TR2 + 0.3 * TR3

# %% [markdown]
# # random forest

# %%
rf_oof = np.zeros(train_df.shape[0])
rf_val_aucs = []
rf_clf = RandomForestClassifier(n_estimators= 100,  min_samples_leaf=10,max_features='sqrt',oob_score=True)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for i, (trn_idx, val_idx) in enumerate(skf.split(train_df, train_df['label'])):
        print('--------------------- {} fold ---------------------'.format(i))
        t = time.time()
        trn_x, trn_y = train_df[cols].iloc[trn_idx].reset_index(drop=True), train_df['label'].values[trn_idx]
        val_x, val_y = train_df[cols].iloc[val_idx].reset_index(drop=True), train_df['label'].values[val_idx]
        rf_clf.fit(
            trn_x, trn_y
        )
        val_prob = rf_clf.predict_proba(val_x)[:, 1]
        auc_score = roc_auc_score(val_y, val_prob)
        print('oob_score:', rf_clf.oob_score_)
        print('auc',auc_score,'score:', tpr_weight_funtion(val_y, val_prob))
        rf_oof[val_idx] = rf_clf.predict_proba(val_x)[:, 1]
        rf_val_aucs.append(auc_score)
print('val_auc', rf_val_aucs, np.mean(rf_val_aucs), np.var(rf_val_aucs))
rf_cv_score = tpr_weight_funtion(train_df['label'], rf_oof)
print('\ncv_score: ', rf_cv_score)
# Out:
# --------------------- 0 fold ---------------------
# oob_score: 0.95571875
# auc 0.9292133878796871 score: 0.437568058076225
# --------------------- 1 fold ---------------------
# oob_score: 0.95596875
# auc 0.9199488158924121 score: 0.3936479128856624
# --------------------- 2 fold ---------------------
# oob_score: 0.9563125
# auc 0.9308735578582881 score: 0.41179673321234117
# --------------------- 3 fold ---------------------
# oob_score: 0.95553125
# auc 0.9268998145596913 score: 0.4469202898550724
# --------------------- 4 fold ---------------------
# oob_score: 0.9558125
# auc 0.9220936658416228 score: 0.4043478260869565
# val_auc [0.9292133878796871, 0.9199488158924121, 0.9308735578582881, 0.9268998145596913, 0.9220936658416228] 0.9258058484063403 1.7314979111892038e-05
#
# cv_score:  0.4223068552774755

# %% [markdown]
# # GBDT

# %%
gbdt_oof = np.zeros(train_df.shape[0])
gbdt_val_aucs = []
gbdt_clf = GradientBoostingClassifier(n_estimators= 100, learning_rate=0.05, max_depth=8,max_features='sqrt', subsample=0.8)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for i, (trn_idx, val_idx) in enumerate(skf.split(train_df, train_df['label'])):
        print('--------------------- {} fold ---------------------'.format(i))
        t = time.time()
        trn_x, trn_y = train_df[cols].iloc[trn_idx].reset_index(drop=True), train_df['label'].values[trn_idx]
        val_x, val_y = train_df[cols].iloc[val_idx].reset_index(drop=True), train_df['label'].values[val_idx]
        gbdt_clf.fit(
            trn_x, trn_y
        )
        val_prob = gbdt_clf.predict_proba(val_x)[:, 1]
        auc_score = roc_auc_score(val_y, val_prob)
        print('auc',roc_auc_score(val_y, val_prob),'score:', tpr_weight_funtion(val_y, val_prob))
        gbdt_oof[val_idx] = gbdt_clf.predict_proba(val_x)[:, 1]
        gbdt_val_aucs.append(auc_score)
print('val_auc', gbdt_val_aucs, np.mean(gbdt_val_aucs), np.var(gbdt_val_aucs))
gbdt_cv_score = tpr_weight_funtion(train_df['label'], gbdt_oof)
print('\ncv_score: ', gbdt_cv_score)
# Out:
# --------------------- 0 fold ---------------------
# auc 0.9316947499499927 score: 0.44301270417422867
# --------------------- 1 fold ---------------------
# auc 0.925323293373768 score: 0.42286751361161523
# --------------------- 2 fold ---------------------
# auc 0.9367412866049329 score: 0.4620689655172414
# --------------------- 3 fold ---------------------
# auc 0.9295244127399243 score: 0.4579710144927537
# --------------------- 4 fold ---------------------
# auc 0.9241509246719283 score: 0.4409420289855073
# val_auc [0.9316947499499927, 0.925323293373768, 0.9367412866049329, 0.9295244127399243, 0.9241509246719283] 0.9294869334681092 2.066207729107257e-05
#
# cv_score:  0.4438157417482771

# %% [markdown]
# # xgboost

# %%
xgb_oof = np.zeros(train_df.shape[0])
# feat_imp_df = pd.DataFrame({'feat': cols, 'imp': 0})
test_df['prob'] = 0
xgb_val_aucs = []
xgb_clf = XGBClassifier(
    objective='binary:logistic',
    learning_rate=0.05,
    n_estimators=10000,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=1023,
    use_label_encoder=False
)

val_aucs = []
seeds = [42]
for seed in seeds:
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (trn_idx, val_idx) in enumerate(skf.split(train_df, train_df['label'])):
        print('--------------------- {} fold ---------------------'.format(i))
        t = time.time()
        trn_x, trn_y = train_df[cols].iloc[trn_idx].reset_index(drop=True), train_df['label'].values[trn_idx]
        val_x, val_y = train_df[cols].iloc[val_idx].reset_index(drop=True), train_df['label'].values[val_idx]
        xgb_clf.fit(
            trn_x, trn_y,
            eval_set=[(trn_x, trn_y), (val_x, val_y)],
            eval_metric = 'auc',
            early_stopping_rounds=200,
            verbose=50
        )
    #     feat_imp_df['imp'] += clf.feature_importances_ / skf.n_splits
        val_prob = xgb_clf.predict_proba(val_x)[:, 1]
        auc_score = roc_auc_score(val_y, val_prob)
        print('auc',roc_auc_score(val_y, val_prob),'score:', tpr_weight_funtion(val_y, val_prob))
        xgb_oof[val_idx] = xgb_clf.predict_proba(val_x)[:, 1]
        test_df['prob'] += xgb_clf.predict_proba(test_df[cols])[:, 1] / skf.n_splits / len(seeds)
        xgb_val_aucs.append(auc_score)
        
print('xgboost val_auc', xgb_val_aucs, np.mean(xgb_val_aucs), np.var(xgb_val_aucs))
xgb_cv_score = tpr_weight_funtion(train_df['label'], xgb_oof)
print('\ncv_score: ', xgb_cv_score)
# Out:
# --------------------- 0 fold ---------------------
# [0]	validation_0-auc:0.87692	validation_1-auc:0.87117
# [50]	validation_0-auc:0.93745	validation_1-auc:0.92575
# [100]	validation_0-auc:0.95720	validation_1-auc:0.93301
# [150]	validation_0-auc:0.96811	validation_1-auc:0.93631
# [200]	validation_0-auc:0.97752	validation_1-auc:0.93914
# [250]	validation_0-auc:0.98355	validation_1-auc:0.93983
# [300]	validation_0-auc:0.98844	validation_1-auc:0.94066
# [350]	validation_0-auc:0.99188	validation_1-auc:0.94058
# [400]	validation_0-auc:0.99457	validation_1-auc:0.94019
# [450]	validation_0-auc:0.99624	validation_1-auc:0.93969
# [500]	validation_0-auc:0.99748	validation_1-auc:0.93909
# [518]	validation_0-auc:0.99781	validation_1-auc:0.93910
# auc 0.9409138828851678 score: 0.4727767695099818
# --------------------- 1 fold ---------------------
# [0]	validation_0-auc:0.88194	validation_1-auc:0.85997
# [50]	validation_0-auc:0.93755	validation_1-auc:0.91625
# [100]	validation_0-auc:0.95817	validation_1-auc:0.92736
# [150]	validation_0-auc:0.96968	validation_1-auc:0.93275
# [200]	validation_0-auc:0.97876	validation_1-auc:0.93535
# [250]	validation_0-auc:0.98481	validation_1-auc:0.93667
# [300]	validation_0-auc:0.98965	validation_1-auc:0.93765
# [350]	validation_0-auc:0.99284	validation_1-auc:0.93860
# [400]	validation_0-auc:0.99514	validation_1-auc:0.93899
# [450]	validation_0-auc:0.99668	validation_1-auc:0.93904
# [500]	validation_0-auc:0.99784	validation_1-auc:0.93891
# [550]	validation_0-auc:0.99859	validation_1-auc:0.93896
# [600]	validation_0-auc:0.99904	validation_1-auc:0.93883
# [630]	validation_0-auc:0.99925	validation_1-auc:0.93893
# auc 0.939301710189482 score: 0.46098003629764067
# --------------------- 2 fold ---------------------
# [0]	validation_0-auc:0.87594	validation_1-auc:0.86820
# [50]	validation_0-auc:0.93758	validation_1-auc:0.92453
# [100]	validation_0-auc:0.95862	validation_1-auc:0.93185
# [150]	validation_0-auc:0.97000	validation_1-auc:0.93475
# [200]	validation_0-auc:0.97816	validation_1-auc:0.93607
# [250]	validation_0-auc:0.98436	validation_1-auc:0.93702
# [300]	validation_0-auc:0.98887	validation_1-auc:0.93721
# [350]	validation_0-auc:0.99227	validation_1-auc:0.93788
# [400]	validation_0-auc:0.99467	validation_1-auc:0.93771
# [450]	validation_0-auc:0.99634	validation_1-auc:0.93799
# [500]	validation_0-auc:0.99752	validation_1-auc:0.93837
# [550]	validation_0-auc:0.99836	validation_1-auc:0.93742
# [600]	validation_0-auc:0.99894	validation_1-auc:0.93731
# [650]	validation_0-auc:0.99929	validation_1-auc:0.93726
# [661]	validation_0-auc:0.99937	validation_1-auc:0.93708
# auc 0.9385549504324506 score: 0.46787658802177867
# --------------------- 3 fold ---------------------
# [0]	validation_0-auc:0.88440	validation_1-auc:0.87329
# [50]	validation_0-auc:0.94014	validation_1-auc:0.92167
# [100]	validation_0-auc:0.95921	validation_1-auc:0.92700
# [150]	validation_0-auc:0.96987	validation_1-auc:0.93002
# [200]	validation_0-auc:0.97824	validation_1-auc:0.93290
# [250]	validation_0-auc:0.98498	validation_1-auc:0.93431
# [300]	validation_0-auc:0.98946	validation_1-auc:0.93398
# [350]	validation_0-auc:0.99245	validation_1-auc:0.93401
# [400]	validation_0-auc:0.99485	validation_1-auc:0.93386
# [450]	validation_0-auc:0.99634	validation_1-auc:0.93334
# [467]	validation_0-auc:0.99685	validation_1-auc:0.93356
# auc 0.9345632131571164 score: 0.48876811594202896
# --------------------- 4 fold ---------------------
# [0]	validation_0-auc:0.89043	validation_1-auc:0.87788
# [50]	validation_0-auc:0.93864	validation_1-auc:0.91514
# [100]	validation_0-auc:0.95857	validation_1-auc:0.92471
# [150]	validation_0-auc:0.96940	validation_1-auc:0.92806
# [200]	validation_0-auc:0.97723	validation_1-auc:0.93013
# [250]	validation_0-auc:0.98394	validation_1-auc:0.93136
# [300]	validation_0-auc:0.98859	validation_1-auc:0.93228
# [350]	validation_0-auc:0.99184	validation_1-auc:0.93228
# [400]	validation_0-auc:0.99423	validation_1-auc:0.93299
# [450]	validation_0-auc:0.99620	validation_1-auc:0.93319
# [500]	validation_0-auc:0.99750	validation_1-auc:0.93322
# [550]	validation_0-auc:0.99838	validation_1-auc:0.93309
# [600]	validation_0-auc:0.99902	validation_1-auc:0.93312
# [632]	validation_0-auc:0.99927	validation_1-auc:0.93330
# auc 0.9334242778919347 score: 0.45978260869565213
# xgboost val_auc [0.9409138828851678, 0.939301710189482, 0.9385549504324506, 0.9345632131571164, 0.9334242778919347] 0.9373516069112304 8.227960298837124e-06
#
# cv_score:  0.4725788900979325

# %% [markdown]
# # lightgbm

# %%
lgb_oof = np.zeros(train_df.shape[0])
lgb_val_aucs = []
# feat_imp_df = pd.DataFrame({'feat': cols, 'imp': 0})
test_df['prob'] = 0
lgb_clf = LGBMClassifier(
    objective='binary',
    learning_rate=0.05,
    n_estimators=10000,
    num_leaves=32,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=1023,
    metric='auc',
    is_unbalance=True
)
seeds = [42]
for seed in seeds:
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    for i, (trn_idx, val_idx) in enumerate(skf.split(train_df, train_df['label'])):
        print('--------------------- {} fold ---------------------'.format(i))
        t = time.time()
        trn_x, trn_y = train_df[cols].iloc[trn_idx].reset_index(drop=True), train_df['label'].values[trn_idx]
        val_x, val_y = train_df[cols].iloc[val_idx].reset_index(drop=True), train_df['label'].values[val_idx]
        lgb_clf.fit(
            trn_x, trn_y,
            eval_set=[(trn_x, trn_y), (val_x, val_y)],
#             categorical_feature=cate_cols,
            early_stopping_rounds=200,
            verbose=50
        )
    #     feat_imp_df['imp'] += clf.feature_importances_ / skf.n_splits
        val_prob = lgb_clf.predict_proba(val_x)[:, 1]
        auc_score = roc_auc_score(val_y, val_prob)
        print('auc',roc_auc_score(val_y, val_prob),'score:', tpr_weight_funtion(val_y, val_prob))
        lgb_oof[val_idx] = lgb_clf.predict_proba(val_x)[:, 1]
        test_df['prob'] += lgb_clf.predict_proba(test_df[cols])[:, 1] / skf.n_splits / len(seeds)
        lgb_val_aucs.append(auc_score)
        
print('val_auc', lgb_val_aucs, np.mean(lgb_val_aucs), np.var(lgb_val_aucs))
cv_score = tpr_weight_funtion(train_df['label'], lgb_oof)
print('\ncv_score: ', cv_score)
# Out:
# --------------------- 0 fold ---------------------
# Training until validation scores don't improve for 200 rounds
# [50]	training's auc: 0.959127	valid_1's auc: 0.93374
# [100]	training's auc: 0.974177	valid_1's auc: 0.938456
# [150]	training's auc: 0.982646	valid_1's auc: 0.938944
# [200]	training's auc: 0.987993	valid_1's auc: 0.938833
# [250]	training's auc: 0.991827	valid_1's auc: 0.938128
# [300]	training's auc: 0.994127	valid_1's auc: 0.937423
# Early stopping, best iteration is:
# [135]	training's auc: 0.980527	valid_1's auc: 0.939306
# auc 0.9393060957280225 score: 0.40580762250453717
# --------------------- 1 fold ---------------------
# Training until validation scores don't improve for 200 rounds
# [50]	training's auc: 0.960762	valid_1's auc: 0.930801
# [100]	training's auc: 0.974745	valid_1's auc: 0.935006
# [150]	training's auc: 0.982947	valid_1's auc: 0.936351
# [200]	training's auc: 0.988108	valid_1's auc: 0.936675
# [250]	training's auc: 0.992037	valid_1's auc: 0.936685
# [300]	training's auc: 0.99459	valid_1's auc: 0.936291
# [350]	training's auc: 0.996183	valid_1's auc: 0.9363
# Early stopping, best iteration is:
# [189]	training's auc: 0.987133	valid_1's auc: 0.936903
# auc 0.9369028206078405 score: 0.41778584392014523
# --------------------- 2 fold ---------------------
# Training until validation scores don't improve for 200 rounds
# [50]	training's auc: 0.960148	valid_1's auc: 0.932497
# [100]	training's auc: 0.974373	valid_1's auc: 0.935596
# [150]	training's auc: 0.982816	valid_1's auc: 0.936654
# [200]	training's auc: 0.988016	valid_1's auc: 0.937034
# [250]	training's auc: 0.991966	valid_1's auc: 0.937313
# [300]	training's auc: 0.994484	valid_1's auc: 0.937263
# [350]	training's auc: 0.996054	valid_1's auc: 0.936681
# [400]	training's auc: 0.997196	valid_1's auc: 0.935692
# Early stopping, best iteration is:
# [242]	training's auc: 0.991542	valid_1's auc: 0.937543
# auc 0.9375426219526902 score: 0.4588021778584392
# --------------------- 3 fold ---------------------
# Training until validation scores don't improve for 200 rounds
# [50]	training's auc: 0.959924	valid_1's auc: 0.925237
# [100]	training's auc: 0.974179	valid_1's auc: 0.92939
# [150]	training's auc: 0.982587	valid_1's auc: 0.929571
# [200]	training's auc: 0.988237	valid_1's auc: 0.929892
# [250]	training's auc: 0.991766	valid_1's auc: 0.929175
# [300]	training's auc: 0.994299	valid_1's auc: 0.928213
# Early stopping, best iteration is:
# [134]	training's auc: 0.980228	valid_1's auc: 0.930151
# auc 0.9301512223882688 score: 0.4427536231884058
# --------------------- 4 fold ---------------------
# Training until validation scores don't improve for 200 rounds
# [50]	training's auc: 0.959836	valid_1's auc: 0.922561
# [100]	training's auc: 0.973908	valid_1's auc: 0.928702
# [150]	training's auc: 0.982304	valid_1's auc: 0.93125
# [200]	training's auc: 0.987554	valid_1's auc: 0.932079
# [250]	training's auc: 0.991372	valid_1's auc: 0.932463
# [300]	training's auc: 0.993953	valid_1's auc: 0.93212
# [350]	training's auc: 0.995833	valid_1's auc: 0.932281
# [400]	training's auc: 0.997137	valid_1's auc: 0.932066
# Early stopping, best iteration is:
# [223]	training's auc: 0.989593	valid_1's auc: 0.932709
# auc 0.9327092965332586 score: 0.4454710144927536
# val_auc [0.9393060957280225, 0.9369028206078405, 0.9375426219526902, 0.9301512223882688, 0.9327092965332586] 0.9353224114420161 1.1373266817934144e-05
#
# cv_score:  0.4335872324990932

# %% [markdown]
# # stacking

# %%
stacking_level0 = np.zeros((train_df.shape[0], 4))
stacking_level0[:, 0] = rf_oof
stacking_level0[:, 1] = gbdt_oof
stacking_level0[:, 2] = xgb_oof
stacking_level0[:, 3] = lgb_oof

# %%
stacking_level0.shape
# Out:
# (40000, 4)

# %%
from sklearn.linear_model import LogisticRegression
level1_clf = LogisticRegression()
# level1_clf = GradientBoostingClassifier()
level1_clf.fit(stacking_level0, train_df['label'].values)
# Out:
# LogisticRegression()

# %%
pred = level1_clf.predict_proba(stacking_level0)[:, 1]
print('auc',roc_auc_score(train_df['label'].values, pred),'score:', tpr_weight_funtion(train_df['label'].values, pred))
# Out:
# auc 0.9375044745051981 score: 0.4672107363075807
